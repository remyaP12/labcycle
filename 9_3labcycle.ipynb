# %% [markdown]
# <a href="https://colab.research.google.com/github/remyaP12/labcycle/blob/main/9_3labcycle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 9.Input an image and perform the following morphological operations
# i)Dilation
# ii)Erosion
# iii)Opening
# iv)Closing
# Display the results.

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Step 1: Read the image
image = cv2.imread("/content/cat.jpg", 0)   # grayscale

# Step 2: Convert image to binary
_, binary = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# Step 3: Create kernel
kernel = np.ones((5, 5), np.uint8)

# Step 4: Morphological operations
dilation = cv2.dilate(binary, kernel, iterations=1)
erosion = cv2.erode(binary, kernel, iterations=1)
opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)

# Step 5: Display results (Colab-friendly)
print("Original Image")
cv2_imshow(binary)

print("Dilation")
cv2_imshow(dilation)

print("Erosion")
cv2_imshow(erosion)

print("Opening")
cv2_imshow(opening)

print("Closing")
cv2_imshow(closing)
# Out:
# Original Image
# <PIL.Image.Image image mode=L size=666x1000>
# Dilation
# <PIL.Image.Image image mode=L size=666x1000>
# Erosion
# <PIL.Image.Image image mode=L size=666x1000>
# Opening
# <PIL.Image.Image image mode=L size=666x1000>
# Closing
# <PIL.Image.Image image mode=L size=666x1000>
